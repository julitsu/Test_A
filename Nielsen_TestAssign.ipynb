# %%
## По ссылке ниже находится массив данных: это продажи на уровне отдельных транзакций из неких случайно попавших 518 розничных точек за 3 календарных месяца - июль, август, сентябрь.
https://cloud.mail.ru/public/531m/3i51Ga9sG  


Формат файла:
1. Уникальный id точки
2. Субъект РФ, где находится точка
3. EAN код (уникальный идентификатор продукта)
4. Уникальный id транзакции
5. Дата, когда была совершена транзакция
6. Описание продукта (как его зафиксировал для себя каждый магазин)
7. Продажи в штуках
8. Продажи в рублях

На основании этой информации мы можем предложить клиентам, чьи категории встречаются в транзакциях, более глубоко узнать ситуацию на рынке, например, через реализацию следующих задач:
Найти самые часто встречающиеся комбинации продуктов и категорий в чеках (что люди обычно покупают вместе).
Выяснить, насколько сильно различаются потребительские привычки по разным регионам и с чем это может быть связано.
Описать профили магазинов, в которых средние продажи той или иной категории (в штуках или деньгах), значимо выше или ниже относительно среднего уровня.
По результатам этого анализа компания должна сделать вывод, кому из производителей той или иной категории товара данная информация поможет принять правильное бизнес-решение (по ассортименту, цене, географическому расположению, формату магазина) с целью увеличить объем продаж, поскольку мы уверены в качестве присланной розничными точками информации, проверили ее на надежность полученных выводов, и хотим обратить внимание наших клиентов на основные выявленные тренды и зависимости.

В качестве результата работы с данными мы бы хотели получить ключевые выводы и подтверждающую их визуализацию, с указанием ограничений, которые стоит принимать во внимание для интерпретации результатов, сколько точек из 518 участвовали в создании той или иной метрики и почему. Если вы захотите в выводы добавить другие источники информации или какой-то другой разрез данных, который не был указан выше, не проблема. Формат - веб или ppt слайды.


# ee eeeeeeeeeeeeeeeeeeeeee
#ee
